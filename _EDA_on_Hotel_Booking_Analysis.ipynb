# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Group of 2 people
# ##### **Name**    - Anurag Tripathy, Sourav Kumar Gupta

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ### This data set contains booking information of a city hotel and a resort hotel and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.  We will perform EDA(Exploratory Data Analysis) with python to get insight from the data.
# ### This dataset contains 119390 rows and 32 columns. First we will understand the data and after that we do cleaning of data i.e. handling of null values, duplicate values etc and at last we will discuss the insights that we got from our analysis.
#
# ## About dataset :
#
# 1.Hotel
# H1: Resort hotel
# H2: City hotel
# ### 2.is_canceled
# 1: Canceled
# 0: Not canceled
# ### 3.lead_time
# No of days thaat elapsed between entering date of booking into property management system and arrival date
# ### 4.arrival_date_year
# Year of arrival date (2015-2017)
# ### 5.arrival_date_month
# Month of arrival date (Jan - Dec)
# ### 6.arrival_date_week_numberr
# Week number of year for arrival date (1-53)
# ### 7.arrival_date_day_of_month
# Day of arrival date
# ### 8.stays_in_weekend_nights
# No of weekend nights (Sat/Sun) the guest stayed or booked to stay at the hotel
# ### 9.stays_in_week_nights
# No of week nights (Mon - Fri) the guest stayed or booked to stay at the hotel
# ### 10.Types of guests
# ### 11.meal
# Type of meal booked. Undefined/SC – no meal package; BB – Bed & Breakfast; HB – Half board (breakfast and one other meal – usually dinner); FB – Full board (breakfast, lunch and dinner)
# ### 12.country
# ### 13.market_segment (a group of people who share one or more common characteristics, lumped together for marketing purposes)
# TA: Travel agents
# TO: Tour operators
# ### 14.distribution_channel (A distribution channel is a chain of businesses or intermediaries through which a good or service passes until it reaches the final buyer or the end consumer)
# TA: Travel agents
# TO: Tour operator
# Direct booking by customer
# online
# ### 14.is_repeated_guest (value indicating if the booking name was from repeated guest)
# 1: Yes
# 0: No
# ### 15.previous_cancellations
# Number of previous bookings that were cancelled by the customer prior to the current booking
# ### 16.previous_bookings_not_canceled
# Number of previous bookings not cancelled by the customer prior to the current booking
# ### 17.reserved_room_type
# Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# ### 18.assigned_room_type
# Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons.
# ### 19.booking_changes
# Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
# ### 20.deposit_type
# Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories: No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable – a deposit was made with a value under the total cost of stay.
# ### 21.agent
# ID of the travel agency that made the booking
# company
# ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# ### 22.day_in_waiting_list
# Number of days the booking was in the waiting list before it was confirmed to the customer
# ### 23.customer_type
# Contract - when the booking has an allotment or other type of contract associated to it;
# Group – when the booking is associated to a group;
# Transient – when the booking is not part of a group or contract, and is not associated to other transient booking;
# Transient-party – when the booking is transient, but is associated to at least other transient booking
# ### 24.adr (average daily rate)
# average daily rate =  SumOfAllLodgingTransactionTotalNumberOfStayingNight
# ### 25.required_car_parking_spaces
# Number of car parking spaces required by the customer
# ### 26.total_of_special_requests
# Number of special requests made by the customer (e.g. twin bed or high floor)
# ### 27.reservation_status
# Canceled – booking was canceled by the customer;
# Check-Out – customer has checked in but already departed;
# No-Show – customer did not check-in and did inform the hotel of the reason why
# ### 28.reservation_status_date
# Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# ##### **Link** - https://github.com/Anurag89844/Data_science.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ###  Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! i.e., Which hotel has high bookings?  The most busy time for hotel booking and many more.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ###1.  To  provide the best service and a flawless experience to customers from start to finish i.e. Quality food in reasonable price, Enhancing the Infrastructure and High Customer Satisfaction.
# ### 2. Increasing Sales
# ### 3. Decreasing Expenses
# ### 4. Awareness of Marketing Trends

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('/content/drive/MyDrive/Hotel Bookings.csv')

# %%
df

# %%
df.T

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head().T

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())

# %%
# Visualizing the missing values
df.fillna(0, inplace=True)

# %%
df.isnull().sum()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# #The dataset given is a dataset from Hotel industry, and we have to analyse the data of customers and the insights behind it.
#
# #The main purpose of this EDA is to help look at data before making any assumptions. It can help identify obvious errors, as well as better understand patterns within the data, detect outliers or anomalous events, find interesting relations among the variables.
#
# #The above dataset has 119390 rows and 32 columns. There are 31994 duplicate values and 129421 missing values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### Description of individual variable
#  1   hotel : Name of hotel(Resort hotel or city hotel)
#
#  2   is_canceled : If booking was canceled(1) or not(0)
#
#  3   lead_time : Number of days before actual arrival of guests
#
#  4  arrival_date_year : Year of arrival date
#
#  5  arrival_date_month : Month of arrival date
#
#  6   arrival_date_week_number : Week number of year for arrival date
#
#  7   arrival_date_day_of_month : Day of arrival date
#
#  8   stays_in_weekend_nights : Number of weekend nights(Saturday or Sunday)  spent at hotel by guests
#
#  9   stays_in_week_nights : Number of weeknights (Monday to Friday) spent at  the hotel by guest
#
#  10  adults : Number of adults among guests
#
#  11  children : Number of children among guests
#
#  12  babies : Number of babies among guests
#
#  13  meal : Type of meal booked
#
#  14  country : Country of guests
#
#  15  market_segment : Designation of market segment
#
#  16  distribution_channel : Name of booking distribution channel
#
#  17  is_repeated_guest :If booking was from repeated guest(1) or not(0)
#
#  18 previous_cancellations : Number of previous cancellation by customer
#
#  19  previous_bookings_not_canceled : Number of previous not cancellation by customer
#
#  20  reserved_room_type : Code of room type reserved
#
#  21  assigned_room_type : Code of assigned room type
#
#  22  booking_changes : Number of times booking changes
#
#  23  deposit_type : Type of deposit made by guest
#
#  24  agent : Id of agent who made the booking
#
#  25  company : Id of company through which booking was done
#
#  26  days_in_waiting_list : Number of days the booking was in waiting list
#
#  27  customer_type : Type of customer
#
#  28  adr : Average daily rate
#
#  29  required_car_parking_spaces : Number of  carparking spaces required by guest
#
#  30  total_of_special_requests : Number of special requests made by guest
#
#  31  reservation_status : Reservation Status  (canceled or check-out)
#
#  32  reservation_status_date : Date at which last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***
#
#
# ## Data Cleaning
#  ### Meal contains a value 'Undefined' which is equal to SC.

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
meal_types = df['meal'].replace('Undefined','SC',inplace=True)
df['meal'].unique()

# %% [markdown]
# ###Now, we have got rid of this undefined meal type.

# %%
df['reserved_room_type'].value_counts()

# %%
subset=df[(df['children']==0)& (df['adults']==0)& (df['babies']==0)]                             
subset[['adults','babies','children']]

# %% [markdown]
# ### Here we can see that there are 180 rows in which all three columns adults,	babies and children are zero. so that this 180 rows are not the data that is useful for us so that we have to remove these 180 rows. Also, we can say that  these 180 rows are invalid rows for our data.

# %%
subset.T

# %%
Delete=(df['children']==0)& (df['adults']==0)& (df['babies']==0)
Delete

# %%
type(Delete)

# %%
data=df[~Delete]

# %%
data.T

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### As of now, we have deleted the data  which is invalid for precise analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# ### 1. Which hotel has more bookings?

# %%
# Chart - 1 visualization code
preferable_hotel = data['hotel'].value_counts().reset_index()
preferable_hotel.columns=['Hotel type','Number of booking']
preferable_hotel

# %%
plt.pie(preferable_hotel["Number of booking"],autopct="%1.1f%%",radius=1.5,explode=[0.08]*2)
plt.legend(labels=preferable_hotel['Hotel type'].value_counts().index.tolist(),loc=(1.1,0.65))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## As pie chart gives proper visulisation that city hotel has higher bookings.
# ### A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## It is clearly visulised by the graph that city hotel has more bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes, for both hotels the gained insights are positive.
# ### City hotel - Need to provide more services to attract more guests to increase revenue.
# ### Resort hotel - Need to make strategies that how can we attract more guests.

# %% [markdown]
# #### Chart - 2
# ### 2. which meal is the most preferable meal?

# %%
# Chart - 2 visualization code
preferable_meal=sns.countplot(x=data['meal'])
plt.title('Preferred_Meal_Type')                                                                
plt.xlabel("Meal_Type")
preferable_meal

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###By this chart we can clearly understand that BB meal type is the most preferable meal type.This chart gives precise visulization.
# ### Bar charts show the frequency counts of values for the different levels of a categorical or nominal variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### The insight is that BB meal type is most prefered meal type follwed by HB,SC and FB.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### This plot gives positive insight that BB meal type is preferable meal type.

# %% [markdown]
# #### Chart - 3
#
# ### 3. From where the most guests are coming ?

# %%
# Chart - 3 visualization code
top_countries = data[data['is_canceled'] == 0]['country'].value_counts().reset_index()
top_countries.columns = ['country', 'No of guests']
top_countries

# %% [markdown]
# abbreviations for top countries-
#
# PRT- Portugal
#
# GBR- United Kingdom
#
# FRA- France
#
# ESP- Spain
#
# DEU - Germany
#
# ITA -Itlay
#
# IRL - Ireland
#
# BEL -Belgium
#
# BRA -Brazil
#
# NLD-Netherlands
#
# USA-United States Of America
#
# CHE-Switzerland
#
# CN-China
#
# AUT-Australia
#
# SWE-Sweden
#
# and many more.

# %%
plt.figure(figsize=(25,10))
value = data['country'].value_counts().plot(kind='bar')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### This chart represents the trend among the countries that from which country the most of the guests are came from and followed by the other countries

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### It shows that most of the guests came from PRT(Portugal) followed by GBR,   ERA, ESP and so on.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###People from all over the world are staying in these two hotels. Most guests are from Portugal and other countries in Europe.
# ### We can instruct the marketing team to target people of this region.

# %% [markdown]
# #### Chart - 4
# ###  4. Which month has most number of bookings?

# %%
# Chart - 4 visualization code
month_wise_data= data['arrival_date_month'].value_counts().sort_values()
plt.figure(figsize=(15,5))
month_wise_data.plot(kind = "bar",color='r', grid= True)
plt.title('Display Monthwise data')
plt.xlabel('Months')
plt.ylabel('Number of Guests');

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### This chart gives proper visulization about the no. of bookings in particular months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### Number of bookings are higher in august month so that we can say that summer time is most busy time for hotel booking. we can clearly visualize the trend from chart that summer months has more no. of bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### It gives a positive insight that we have to work hard in summers and we can provide attractive offers to guests in winter season to increase the revenue.

# %% [markdown]
# #### Chart - 5
# ### 5. Most prefered room type?

# %%
# Chart - 5 visualization code
most_prefer_room = data['reserved_room_type'].value_counts().reset_index()
most_prefer_room.columns=['room_type','number_of_prefrence']
#Now ploting the graph
sns.barplot(x=most_prefer_room["room_type"],y=most_prefer_room["number_of_prefrence"],palette="Set2")
plt.title("Preference of room type")
plt.ylabel("number of Guest prefrences")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### Bar chart gives proper visulization about the volume of guests prefered which room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### A room type is the most prefered room type follwed by D, E, F, G, B, C, H and L.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes, we got positive insight that room type A is the most prefered room type obviously because of better services experience in that room type. Through this we also get a idea that we have to provide such services to other room types also so that it can maximize the demand of other room types.

# %% [markdown]
# #### Chart - 6
# ###  6. Through which most bookings has done?

# %%
# Chart - 6 visualization code
plt.figure(figsize=(12,5))
sns.countplot(data = data, x = 'market_segment').set_title('Types of market segment', fontsize = 20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### Through this chart we can clearly analyse that through which segment hotel got the most bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###Majority of the distribution channels and market segments involve travel agencies (online or offline).
# ###We can target our marketing area to be on these travel agencies website and work with them since majority of the visitors tend to reach out to them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes this shows positive business impact as higher the number of TA/TO higher will be the revenue.

# %% [markdown]
# #### Chart - 7
# ### 7. Which month has achieved most adr ?

# %%
# Chart - 7 visualization code
#groupby
bookings_by_months=data.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

#create month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# it will take the order of the month list in the df along with values
bookings_by_months['arrival_date_month']=pd.Categorical(bookings_by_months['arrival_date_month'],categories=months,ordered=True)

#sortting
bookings_by_months=bookings_by_months.sort_values('arrival_date_month')

bookings_by_months

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months['arrival_date_month'],y=bookings_by_months['adr'],hue=bookings_by_months['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### This chart provides a proper view of Adr between  both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### For Resrot hotel ADR is high in the months June,July,August as compared to City Hotels. May be Customers/People wants to spend their Summer vaccation in Resorts Hotels.
# ###The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### This gives us a view that in which season we have to advertise so that more customers will attract.

# %% [markdown]
# #### Chart - 8
# ### 8. Are guests repeated?

# %%
data['is_repeated_guest'].value_counts().plot.pie(explode=[0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(12,8),fontsize=20)
plt.title("Percentage Of Repeated Guests(1)")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### As this chart show the accurate percentage of non-repeated guests and repeated guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can clearly see that only 3.1% of repeated guests

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Repeated guests are only 3.1%, so to retain the guests, it is important to take feedback from them, with the help of these feedbacks hotel management should make some improvements according to the guest needs and provide services to reach the guests also we can give attractive offers to non-repeititive guests during the Off season to enhance the revenue. By doing this we can tackle two things i.e. guests will come in off season and also number of repeititive guests will increase.

# %% [markdown]
# #### Chart - 9
# ### 9. Which guest type made the highest bookings?

# %%
# Chart - 10 visualization code
sns.countplot(data = data, x = 'customer_type').set_title('Graph showing type of guest', fontsize = 20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### As this chart gives proper information about that which type of guest made most of the bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###  Majority of the bookings are transient.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### This means that the booking is not part of a group or contract. With the ease of booking directly from the website, most people tend to skip the middleman to ensure quick response from their booking.

# %% [markdown]
# #### Chart - 10
# ### Bookings done with deposite or not?

# %%
# Chart - 11 visualization code
sns.countplot(data = data, x = 'deposit_type').set_title('Graph showing types of deposits', fontsize = 20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  As this chart gives proper information  that most of the bookings are made from which deposit type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### It is clear that almost all guests made no deposit booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ###Majority of the booking does not do any deposit.

# %% [markdown]
# #### Chart - 11
# ### 10. Which year had highest booklings?

# %%
# Chart - 12 visualization code
sns.countplot(data=df , x="arrival_date_year" , hue="hotel" )
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###  Here this chart gives the best comparison of bookings among the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### 1. 2016 had the higest bookings.
#
# ### 2.2015 had the least bookings.
#
# ### 3.Overall City hotel had the most number of the bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### This gives us a view that on which year which hotel got highest or lowest   bookings.

# %% [markdown]
# #### Chart - 12 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(18,10))
sns.heatmap(data.corr(),annot=True)
plt.title('Co-relation of the columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ###To visualise the relationship between variables . A heatmap is a effective tool to identify highly correlated variables.A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1].

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ###Lead_time and Total_stay is positively corelated.
# ### That means more is the stay of cutsomer more will be the lead time.
#
# ###2)Adults,childrens and babies are corelated to each other. That means more the people more will be adr.
#
# ### "is_canceled" and "same_room_alloted_or_not" are negatively corelated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
#
# ### "is_repeated guest" and "previous bookings not canceled" has strong corelation. may be repeated guests are not more likely to cancel their bookings.
#
# ###"adr" and "total_number_of_people" are positively correlated, so if people increase, ADR will automatically increase which means hotels can earn huge revenue.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes this provides positive business impact as this chart shows the highly correlated variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ### 1. Analyze when the slow periods are during the week, by day and time of day. Develop a strategy to bring in more customers during those times. For example, if lunch business is slow, give attractive offers to customers for lunch.
#
# ### 2. Customers are likely to visit a restaurant if it was recommended to them by a friend or family member . Train your staff to thank loyal customers each time they dine at your restaurant and encourage customers to tell their friends and colleagues about the restaurant.
#
# ### 3. Improve kitchen efficiency. Business can be lost if customers have to wait too long for their meals because they may decide they don't want to come again. Review the kitchen organization, food preparation steps and staffing levels to look for ways to get the food to customers more quickly.
#
# ### 4. Use social media and the Internet for publicity of hotel.
#
# ### 5. Vary the menu. Announce upcoming new dishes through advertisement because people are always excited about trying the new menu items.
#
# ###6. Survey customers about what would make the restaurant better. Create an online suggestion box that gives a discount coupon to each person who posts an idea. Create customer survey cards and hand them out to customers as they pay their bill.
#
# ### 7. Develop a group pricing strategy. Offer discounts for groups from local companies, sports teams, schools and organizations.
#
# ###8.  Decorate the hotel will also attract customers as people always attracts by facinating things.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### 1. Majority of the hotel bookings are in city hotel. Definitely need to spend the most targeting fund on those hotel.
# ### 2. BB( Bed & Breakfast) is the most preferred type of meal by the guests.
# ### 3. We also realise that the high rate of cancellations can be due high no deposit policies.
# ### 4. Most of the bookings for City hotels and Resort hotel were happened in 2016.
# ### 5. Given that we do not have repeated guests, we should target our advertisement on guests to increase returning guests.
# ### 6. Room Type A is the most preferred room type among travrllers.
# ###  7. Most of the bookings were made through TA/TO (travel agents/Tour operators).
# ### 8. We have a huge number of visitors from western europe, namely France,UK and Portugal being the highest.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
